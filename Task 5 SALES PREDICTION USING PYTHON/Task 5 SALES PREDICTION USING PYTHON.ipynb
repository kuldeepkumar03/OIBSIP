# %% [markdown]
# **importing all the necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the csv dataset as a pandas dataframe.**

# %%
df=pd.read_csv("Advertising.csv")

# %% [markdown]
# **Data Understanding**

# %%
pd.concat([df.head(),df.tail()])
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
plt.figure(figsize=(20,10))       #Distribution of sales
sns.distplot(df['Sales'])
# Out:
# C:\Users\deepk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
plt.figure(figsize=(20,10))       #Distribution of TV
sns.distplot(df['TV'])
# Out:
# C:\Users\deepk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='TV', ylabel='Density'>

# %%
plt.figure(figsize=(20,10))       #Distribution of Radio
sns.distplot(df['Radio'])
# Out:
# C:\Users\deepk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
plt.figure(figsize=(20,10))       #Distribution of newspaper
sns.distplot(df['Newspaper'])
# Out:
# C:\Users\deepk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
df.duplicated().value_counts()
# Out:
# False    200
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df1=df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
x=df.iloc[:,:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=model.predict(x_test)
ypred
# Out:
# array([10.31959461, 21.60676891,  4.6100282 , 14.76339842, 13.18022307,
#        24.39683117,  9.72325913,  8.70854693, 19.48509203, 17.157541  ,
#         8.10353903,  5.8257179 ,  7.13252217, 20.2509995 , 12.86215187,
#        11.62066753, 15.71432723, 15.82036791, 19.6006629 , 13.45548408,
#        14.99771931,  8.81519488, 12.4206963 ,  6.60778763, 21.22662884,
#        10.86276011, 10.80778804,  9.8243367 ,  5.26607029, 13.94590606,
#        13.79763985, 17.16528678,  8.39747935, 17.95307784,  9.30265681,
#         8.16279222, 14.17671052, 14.09963834, 14.86491648,  9.08724784,
#        16.55275352, 15.62404119, 16.92347167, 13.79881507, 15.84152284,
#         6.61508336, 11.51126736, 12.65699999, 15.1019066 ,  8.94075855,
#        21.55841092,  8.19859618, 24.14594497, 10.58135687, 20.27046125,
#        17.1600006 , 17.07842105, 19.43718612, 21.64806736,  7.78875156])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ypred,y_test)*100
# Out:
# 85.09897413482153

# %%
figsize=(30, 25)

ax1 = sns.distplot(df['Sales'], hist=False, color="r", label="Actual Value")
sns.distplot(ypred, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')
plt.legend()
plt.show()
# Out:
# C:\Users\deepk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\deepk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
